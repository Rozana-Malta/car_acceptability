# %% [markdown]
# Importando as bibliotecas

# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/car.csv')

# %%
df.head()
# Out:
#   Buying_Price Maintenance_Price No_of_Doors Person_Capacity Size_of_Luggage
# 0        vhigh             vhigh           2               2           small  \
# 1        vhigh             vhigh           2               2           small
# 2        vhigh             vhigh           2               2           small
# 3        vhigh             vhigh           2               2             med
# 4        vhigh             vhigh           2               2             med
#
#   Safety Car_Acceptability
# 0    low             unacc
# 1    med             unacc
# 2   high             unacc
# 3    low             unacc
# 4    med             unacc

# %%
# histograma cada coluna do dataset
df['Car_Acceptability'].hist(figsize=(20,10));

# %% [markdown]
# Separando os dados de acordo com a aceitabilidade

# %%
unacc = df[df["Car_Acceptability"]=="unacc"]

# %%
fig = px.pie(df, values='No_of_Doors', names='Car_Acceptability')
fig.show()
